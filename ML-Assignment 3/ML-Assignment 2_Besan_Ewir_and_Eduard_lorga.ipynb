# %% [markdown]
# # Machine Learning - Assignment 3
#
# ## Artificial Neural Network

# %% [markdown]
# ## <span style="color:#1f77b4">Besan Ewir and Eduard Iorga /group 27</span>

# %% [markdown]
# The aim of the assignment is to implement an artificial neural network (mostly) from scratch. This includes implementing or fixing the following:
#
# * Add support for additional activation functions and their derivatives.
# * Add support for loss functions and their derivative.
# * Add the use of a bias in the forward propagation.
# * Add the use of a bias in the backward propagation.
#
# In addition, you will we doing the following as well:
#
# * Test the algorithm on 3 datasets.
# * Compare neural networks with and without scaling.
# * Hyper-parameter tuning.
#
# The forward and backward propagation is made to work through a single layer, and are re-used multiple times to work for multiple layers.
#
# Follow the instructions and implement what is missing to complete the assignment. Some functions have been started to help you a little bit with the implementation.
#
# **Note:** You might need to go back and forth during your implementation of the code. The structure is set up to make implementation easier, you might find yourself going back and and forth to change something to make it easier later on.

# %% [markdown]
# ## Assignment preparations

# %% [markdown]
# We help you out with importing the libraries.
#
# **IMPORTANT NOTE:** You may not import any more libraries than the ones already imported!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# We set seed to better reproduce results later on.
np.random.seed(12345)

# %% [markdown]
# ## Neural Network utility functions

# %% [markdown]
# ### 1) Activation functions
#
# Below is some setup for choosing activation function. Implement 2 additional activation functions, "ReLU" and one more of your choosing.

# %%
# Activation functions
def activate(activations, selected_function = "none"):
    
    if selected_function == "none":
        y = activations
    elif selected_function == "relu" :
        y=np.maximum(0,activations)
    elif selected_function == "sigmoid" :
        y=1/(1+np.exp((-activations)))
    return y

# %%
test_data = np.array([-2, -1, 0, 1, 2])
print("Sigmoid results",activate(test_data,selected_function="sigmoid"))
print("Relu results",activate(test_data,selected_function="relu"))
# Out:
# Sigmoid results [0.11920292 0.26894142 0.5        0.73105858 0.88079708]
# Relu results [0 0 0 1 2]

# %% [markdown]
# ### 2) Activation function derivatives
#
# Neural networks need both the activation function and its derivative. Finish the code below.

# %%
def d_activate(activations, selected_function = "none"):
    if selected_function == "none":
        dy = np.ones_like(activations)
    elif selected_function == "relu":
        dy=np.where(activations>0,1,0)
    elif selected_function == "sigmoid":
        y=activate(activations,selected_function="sigmoid")
        dy=y*(1-y)
    return dy

# %%
test_data = np.array([-2, -1, 0, 1, 2])
print("Sigmoid results",d_activate(test_data,selected_function="sigmoid"))
print("Relu results",d_activate(test_data,selected_function="relu"))
# Out:
# Sigmoid results [0.10499359 0.19661193 0.25       0.19661193 0.10499359]
# Relu results [0 0 0 1 1]

# %% [markdown]
# ### 3) Loss functions
#
# To penalize the network when it predicts incorrect, we need to meassure how "bad" the prediction is. This is done with loss-functions.
#
# Similar as with the activation functions, the loss function needs its derivative as well.
#
# Finish the MSE_loss (Mean Squared Error loss), as well as adding one additional loss function.

# %%
# This is the loss for a set of predictions y_hat compared to a set of real valyes y
def MSE_loss(y_hat, y):
    square_error=(y_hat-y)**2
    loss = np.mean(square_error)
    return loss

#Binary Cross-Entropy because we use Sigmoid Function above for activation
def Binary_CE(y_hat, y):
    epsilon=1e-15
    y_hat=np.clip(y_hat,epsilon,1-epsilon)
    loss = -np.mean(y*np.log(y_hat)+(1-y)*np.log(1-y_hat))
    return loss

# %% [markdown]
# The derivatives of the loss is with respect to the predicted value **y_hat**.

# %%
def d_MSE_loss(y_hat, y):
    dy = 2 * (y_hat - y) / y.size
    return dy

#Binary Cross-Entropy because we use Sigmoid Function above for activation
def d_Binary_CE(y_hat, y):
    epsilon=1e-15
    y_hat=np.clip(y_hat,epsilon,1-epsilon)
    dy = -(y/y_hat - (1-y)/(1-y_hat)) / y.size
    return dy

# %%
y_hat = np.array([0.9, 0.2, 0.8])
y     = np.array([1.0, 0.0, 1.0])
print(d_MSE_loss(y_hat, y))
print(d_Binary_CE(y_hat, y))
# Out:
# [-0.06666667  0.13333333 -0.13333333]
# [-0.37037037  0.41666667 -0.41666667]

# %% [markdown]
# ### 4) Forward propagation
#
# The first "fundamental" function for neural networks is to be able to propagate the data forward through the neural network. We will implement this function here.

# %%
def propagate_forward(weights, activations, bias, activation_function="none"):
    
    # TODO: Add support for the use of bias

    dot_product = np.dot(activations, weights) + bias
    new_activations = activate(dot_product, activation_function)
    return new_activations

# %%
activations = np.array([
    [1, 2, 3],
    [4, 5, 6]
])          # shape (2,3)  ← (samples, features)

# weights
weights = np.ones((3,4))   # shape (features, neurons)

# bias
bias = np.zeros((1,4))
out = propagate_forward(weights, activations, bias, activation_function="none")
print(out)          # bias
# Out:
# [[ 6.  6.  6.  6.]
#  [15. 15. 15. 15.]]

# %% [markdown]
# ### 5) Back-propagation
#
# To be able to train a neural network, we need to be able to propagate the loss backwards and update the weights. We will implement this function here.

# %%
# Calculates the backward gradients that are passed throught the layer in the backward pass.
# Returns both the derivative of the loss in respect to the weights and the input signal (activations).

def propagate_backward(weights, activations, dl_dz, bias, activation_function="none"):
    # NOTE: dl_dz is the derivative of the loss based on the previous layers activations/outputs

    # TODO: Add support for the use of bias

    dot_product = np.dot(activations, weights) + bias 
    
    d_loss = d_activate(dot_product, activation_function) * dl_dz
    d_bias = np.sum(d_loss, axis=0, keepdims=True)
    d_weights = np.dot(activations.T, d_loss)
    d_activations = np.dot(d_loss, weights.T)
    
    return d_weights, d_bias, d_activations

# %%
activations = np.array([[2],
                        [1]])    
weights = np.array([[2, 3]])
bias        = np.array([[0, 0]])     # shape (1,2)
dl_dz = np.array([[1, 1],
                  [1, 1]])     # shape (1,2)

dW, db, dA = propagate_backward(weights, activations, dl_dz, bias, activation_function="none")

print("dW =", dW)
print("db =", db)
print("dA =", dA)
# Out:
# dW = [[3 3]]
# db = [[2 2]]
# dA = [[5]
#  [5]]

# %% [markdown]
# ## Neural network implementation
#
# ### 6) Fixing the neural network
#
# Below is a class implementation of a MLP neural network. This implementation is still lacking several areas that are needed for the network to be robust and function well. Your task is to improve and fix it with the following:
#
# 1. Add a bias to the activation functions, and make sure the bias is also updated during training.
# 2. Add a function that trains the network using minibatches (such that the neural network trains on a few samples at a time).
# 3. Make use of an validation set in the training function. The model should stop training when the loss starts to increase for the validatin set. This feature should be able to be turned on and off to test the difference.

# %%
class NeuralNet(object):
    
    # Setup all parameters and activation functions.
    # This function runs directly when a new instance of this class is created.
    def __init__ (self, input_dim, output_dim, neurons = []):

        # NOTE: The "neurons" parameter is given as a list.
        # E.g., [4, 8, 4] means 4 neurons in layer 1, 8 neurons in layer 2 etc...
        
        self.weights = [
            np.random.normal(0, np.sqrt(2/n), (n, m))
            for n, m in zip([input_dim] + neurons, neurons + [output_dim])
        ]
        
        # Bias for each neuron in every layer (start with zeros)
        self.biases = [np.zeros((1, m)) for m in neurons + [output_dim]]

        self.activation_functions = ["relu"] * len(neurons) + ["none"]
    
    
    # Predict the input throught the network and calculate the output.
    def forward(self, x):

        for layer_weights, layer_bias, layer_activation_function in zip(
            self.weights, self.biases, self.activation_functions
            ):
            x = propagate_forward(layer_weights, x, layer_bias, layer_activation_function)

        return x
    
    
    # Adjust the weights in the network to better fit the desired output (y), given the input (x).
    # The weight updates are happening "in-place", thus we are only returning the loss from this function.
    # Note that this function can handle a variable size of the input (x), both full datasets or smaller parts of the dataset.
    def adjust_weights(self, x, y, learning_rate=1e-4):

        activation = x
        activation_history = [] # NOTE: We need the previous (or intermediate) activations to make use of the "chain rule" (see lecture notes).

        # ---------- Forward pass ----------
        for layer_weights, layer_bias, layer_activation_function in zip(
            self.weights, self.biases, self.activation_functions
            ):
            activation_history.append(activation)
            activation = propagate_forward(layer_weights, activation, layer_bias, layer_activation_function)
           
        # NOTE: The "activation" variable is changing as we go forward in the neural network.

        # ---------- Compute loss ----------
        loss = MSE_loss(activation,y)
        d_activations = d_MSE_loss(activation,y) # NOTE: The final output can be "seen as" the final activations, thus the name.
        
            #loss=d_Binary_CE(activation,y)
            #d_activations=d_Binary_CE(activation,y)
        # ---------- Backward pass ----------
        for i in reversed(range(len(self.weights))):
            layer_weights = self.weights[i]
            layer_bias = self.biases[i]
            layer_activation_function = self.activation_functions[i]
            previous_activations = activation_history[i]

            d_weights, d_bias, d_activations = propagate_backward(layer_weights, previous_activations, d_activations, layer_bias, layer_activation_function)

            #  Here is where the weight and bias update is happening.
            layer_weights -= learning_rate * d_weights
            layer_bias -= learning_rate * d_bias
                        
        return loss
    
    
    # A function for the training of the network.
    def train_net(self, x, y, batch_size=32, epochs=100, learning_rate=1e-4, use_validation_data=False):

        # ---------- split into train/validation ----------
        if use_validation_data:
            # shuffle once before split
            idx = np.random.permutation(len(x))
            x = x[idx]
            y = y[idx]

            split = int(0.8 * len(x))   # 80% train, 20% validation
            x_train, y_train = x[:split], y[:split]
            x_val, y_val     = x[split:], y[split:]

            best_val_loss = np.inf
            best_weights = [w.copy() for w in self.weights]
            best_biases  = [b.copy() for b in self.biases]
        else:
            x_train, y_train = x, y

        train_losses = []
        val_losses = []

        # ---------- Epoch loop ----------
        for epoch in range(epochs):

            # shuffle training data each epoch
            idx = np.random.permutation(len(x_train))
            x_train = x_train[idx]
            y_train = y_train[idx]

            epoch_losses = []

            # ----------  Mini-batch loop ----------
            for start in range(0, len(x_train), batch_size):
                end = start + batch_size
                x_batch = x_train[start:end]
                y_batch = y_train[start:end]

                batch_loss = self.adjust_weights(x_batch, y_batch, learning_rate=learning_rate)
                epoch_losses.append(batch_loss)

            # average training loss for the epoch
            train_loss = float(np.mean(epoch_losses))
            train_losses.append(train_loss)
        
            # ---------- Validation + early stopping ----------
            if use_validation_data:
                y_val_pred = self.forward(x_val)
                val_loss = float(MSE_loss(y_val_pred, y_val))
                val_losses.append(val_loss)

                # stop if validation loss starts increasing
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    best_weights = [w.copy() for w in self.weights]
                    best_biases  = [b.copy() for b in self.biases]
                else:
                    # restore best model before stopping
                    self.weights = [w.copy() for w in best_weights]
                    self.biases  = [b.copy() for b in best_biases]
                    break

        # returning losses is useful for plotting later
        if use_validation_data:
            return train_losses, val_losses
        return train_losses

# %% [markdown]
# ## Train Neural Networks

# %% [markdown]
# ### 7) Simple test
#
# In this a very simple test for you to use and toy around with before using the datasets.
#
# Make sure to test both the **adjust_weights** function and the **train_net** function. What is the difference between the two?
#
# Also, be sure to **plot the loss for each epoch** to see how the network training is progressing!

# %%
# TODO: You can change most things in this cell if you want to, we encurage it!
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)  # reset allt
plt.close('all')

n = 1000
d = 4

k = np.random.randint(0,10,(d,1))
x = np.random.normal(0,1,(n,d))
y = np.dot(x,k) + 0.1 + np.random.normal(0,0.01,(n,1))

                        
nn = NeuralNet(d, 1, [18, 12])

loss_1 = [nn.adjust_weights(x, y) for _ in range(1000)] 

loss_2 = nn.train_net(x, y, batch_size=32, epochs=1000, learning_rate=1e-4, use_validation_data=False)
plt.figure(figsize=(8,4), dpi=100)
plt.plot(loss_1)
plt.title("Loss 1 (adjust_weights) - raw loss from random initialization")
#plt.text(100, 15000, "Starts high due to random initialization,\nfull dataset updates cause sharp drop at first.")
plt.show()

plt.figure(figsize=(8,4), dpi=100)
plt.plot(loss_2)
plt.title("Loss 2 (train_net) - smaller scale due to epoch averaging and mini-batches")
#plt.text(100, 6, "Smoother curve due to mini-batch averaging\nand starting after initial training.")
plt.show()
print("Final loss adjust:", loss_1[-1])
print("Final loss train:", loss_2[-1])
# Out:
# Final loss adjust: 7.1130627920692335
# Final loss train: 0.0954537292262101

# %% [markdown]
# ### Real test and preprocessing
#
# When using real data and neural networks, it is very important to scale the data between smaller values, usually between 0 and 1. This is because neural networks struggle with larger values as input compared to smaller values.
#
# To test this, we will use our first dataset and test with and without scaling.
#
# Similar as with assignment 2, we will use the scikit-learn library for this preprocessing: https://scikit-learn.org/stable/modules/preprocessing.html

# %% [markdown]
# ### 8) Dataset 1: Wine - with and without scaling
#
# Read about the Wine dataset: https://archive.ics.uci.edu/dataset/109/wine
#
# Train two neural network, one with scaling and one without. Are we able to see any difference in training results or loss over time?
#
# **Note:** Do not train for to many epochs (more than maybe 50-100). The network might "learn" anyway in the end, but you should still be able to see a difference when training.

# %%
from sklearn import preprocessing # For one-hot-encoding and scaling if needed
from sklearn.model_selection import train_test_split

data_wine = pd.read_csv("wine.csv",skiprows=[1])

# Function to calculate accuracy
# model.forward(xt) gives predictions
# argmax selects the class with highest value
def calc_acc(model,xt,yt):
        preds=np.argmax(model.forward(xt),axis=1)
        real=np.argmax(yt,axis=1)
        return np.mean(preds==real)
    
x=data_wine.iloc[:,:-1].values
y=data_wine.iloc[:,-1].values

y_indices=(y-1).astype(int)
y_onehot=np.eye(3)[y_indices]

# TODO: Do the above at least 3 times
# NOTE: Use loops here!
all_unscaled_loss=[]
all_scaled_loss=[]
final_acc_unscaled=[]
final_acc_scaled=[]

for i in range(3):
    print(f"Executing Run {i+1} ")

    indices=np.arange(len(x))
    idx_train,idx_val=train_test_split(indices,test_size=0.2 , random_state=42)
    
    # split into train and validation sets
    x_train,x_val=x[idx_train],x[idx_val]
    y_train,y_val=y_onehot[idx_train],y_onehot[idx_val]
    
    # ----- SCALING ----- 
    scaler=preprocessing.StandardScaler()

     # fit on TRAIN only (learn mean and std) + scale train data
    x_train_s =scaler.fit_transform(x_train) 

    # scale validation using same mean/std (no new fit!)
    x_val_s=scaler.transform(x_val)

    # create two neural networks
    # one for unscaled data, one for scaled data
    neural_network_unscaled= NeuralNet(input_dim=13,output_dim=3,neurons=[8,8])
    neural_network_scaled= NeuralNet(input_dim=13,output_dim=3,neurons=[8,8])

    # train with raw data (small learning rate)
    unscaled_loss=neural_network_unscaled.train_net(x_train, y_train,epochs=100,learning_rate=1e-5)
    all_unscaled_loss.append(unscaled_loss)

    # train with scaled data (larger learning rate)
    scaled_loss=neural_network_scaled.train_net(x_train_s, y_train,epochs=100,learning_rate=1e-2)
    all_scaled_loss.append(scaled_loss)

    # calculate validation accuracy
    final_acc_unscaled.append(calc_acc(neural_network_unscaled,x_val,y_val))
    final_acc_scaled.append(calc_acc(neural_network_scaled,x_val_s,y_val))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(np.mean(all_unscaled_loss, axis=0), label='Unscaled (Avg)', color='red', linestyle='--')
plt.plot(np.mean(all_scaled_loss, axis=0), label='Scaled (Avg)', color='green')
plt.yscale('log')
plt.title('Training Loss (50 Epochs)')
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
#plt.ylim(0,1)
plt.legend()
plt.subplot(1, 2, 2)
labels = ['Run 1', 'Run 2', 'Run 3']
x = np.arange(len(labels))
plt.bar(x - 0.2, final_acc_unscaled, 0.4, label='Unscaled', color='red')
plt.bar(x + 0.2, final_acc_scaled, 0.4, label='Scaled', color='green')
plt.xticks(x, labels)
plt.ylabel('Accuracy (%)')
plt.title('Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
print(all_scaled_loss[0][:5]) # Printing the first 5 loss values of the first run for scaled data to verify the results.
# Out:
# Executing Run 1
# Executing Run 2
# Executing Run 3
# [1.3944085873372547, 0.9391326578668402, 0.7248434173529597, 0.6103116153290629, 0.5073942174169368]

# %% [markdown]
# ## Real data and hyper-parameter tuning
#
# Now we are going to use real data, preprocess it, and do hyper-parameter tuning.
#
# Choose two hyper-parameters to tune to try and achive an even better result. **Each chosen parameter needs to have at least 3 different values**. For example, if we were to choose "epochs" then we could test 10, 50, and 100 (optionally more).
#
# To better see what each hyper-parameter does to the models performance, we recommend doing a *grid-search* on the two chosen parameters. A grid-search tests how the two parameters interact with eachother. There might be a setting in parameter 1 that in combination with a setting in parameter 2 makes the model perform significantly better, compared to the other combinations. A grid-search test all these combinations.
#
# **IMPORTANT NOTE:** Changing the **number of epochs** can be part of the tuning, but it **does not count** towards the two hyper parameters you choose.

# %% [markdown]
# ### 9) Dataset 2: Mushroom
#
# Read about the Mushroom dataset: https://archive.ics.uci.edu/dataset/73/mushroom

# %%
from sklearn import preprocessing # For one-hot-encoding and scaling if needed
from sklearn.model_selection import train_test_split

data_mushroom = pd.read_csv("mushroom.csv")

data_mushroom = data_mushroom[data_mushroom["stalk-root"] != "?"].copy()
data_oh = pd.get_dummies(data_mushroom)

x_m = data_oh.iloc[:, 1:].values.astype(float)
y_m = data_oh.iloc[:, 0].values.astype(float).reshape(-1, 1)


x_train_m,x_test_m,y_train_m,y_test_m = train_test_split(x_m,y_m,test_size=0.2,random_state=42)

X_tr_m, X_val_m, y_tr_m, y_val_m = train_test_split(
    x_train_m, y_train_m, test_size=0.2, random_state=42, stratify=y_train_m.ravel().astype(int)
)
nn = NeuralNet(input_dim=x_train_m.shape[1], output_dim=1, neurons=[16,8])


def calc_acc_binary(model, xt, yt):
    y_hat = model.forward(xt)              # (n,1)
    preds = (y_hat >= 0.5).astype(int)     # threshold
    return np.mean(preds == yt)

epochs = 50
loss_history = []
acc_history  = []

for ep in range(epochs):
    loss_ep = nn.train_net(x_train_m, y_train_m, batch_size=32, epochs=1, learning_rate=1e-3)
    
    loss_history.append(loss_ep[0])
    

    acc = calc_acc_binary(nn, x_test_m, y_test_m)
    acc_history.append(acc)

plt.figure()
plt.plot(loss_history)
plt.title("Training loss per epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

plt.figure()
plt.plot(acc_history)
plt.title("Test accuracy per epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim(0, 1.05)
plt.show()

# %% [markdown]
# When hyper-parameter tuning, please write the parameters and network sizes you test here:
#
# * Parameter 1:
# * Parameter 2:
#
# * Neural network sizes:

# %%
# TODO: Hyper-parameter tuning
# --------- Hyper-parameter tuning (GRID SEARCH) ---------

x_tr, x_val, y_tr, y_val = train_test_split(
    x_train_m, y_train_m, test_size=0.2, random_state=42,
    stratify=y_train_m.ravel().astype(int)
) 

learning_rates = [1e-4, 1e-3, 1e-2]
hidden_sizes   = [[8,4], [16,8], [32,16]]

results = []  # (lr, hidden, final_acc)

# GRID SEARCH on VALIDATION SET
for lr in learning_rates:
    for hs in hidden_sizes:
        print(f"Testing lr={lr}, hidden={hs}")
        #  create a NEW network for each experiment
        nn_tmp = NeuralNet(input_dim=x_tr.shape[1], output_dim=1, neurons=hs)

        # Train for some epochs (not too many for tuning)
        epochs = 30
        for ep in range(epochs):
            nn_tmp.train_net(x_tr, y_tr, batch_size=32, epochs=1, learning_rate=lr)

        # Evaluate on test set
        val_acc = calc_acc_binary(nn_tmp, x_val, y_val)
        results.append((lr, hs, val_acc))
        print(f"lr={lr}, hidden={hs} -> acc={val_acc:.4f}")

# Find the best combination (highest accuracy)
best_lr, best_hs, best_acc = max(results, key=lambda t: t[2])

print("\nBEST SETUP:")
print("learning_rate =", best_lr)
print("hidden_sizes  =", best_hs)
print("best accuracy =", best_acc)


# -----------------------------
# Train best model again, and track curves per epoch
# -----------------------------
nn_best = NeuralNet(input_dim=x_train_m.shape[1], output_dim=1, neurons=best_hs)

epochs = 50
best_loss_history = []
best_acc_history  = []

for ep in range(epochs):
    # Train 1 epoch
    loss_ep = nn_best.train_net(x_train_m, y_train_m, batch_size=32, epochs=1, learning_rate=best_lr)
    best_loss_history.append(loss_ep[0])

    # Test accuracy after this epoch
    acc_val = calc_acc_binary(nn_best, x_val, y_val)
    best_acc_history.append(acc_val)

final_test_acc = calc_acc_binary(nn_best, x_test_m, y_test_m)
print("\nFINAL TEST ACC:", final_test_acc)

# Plot loss
plt.figure()
plt.plot(best_loss_history)
plt.title("Training loss per epoch (best model)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# Plot test accuracy
plt.figure()
plt.plot(best_acc_history)
plt.title("Validation accuracy per epoch (best model)")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim(0,1.05)
plt.show()

# TODO: Visualize the loss after hyper-parameter tuning for each epoch

# TODO: Visulaize the test accuracy after hyper-parameter tuning for each epoch
# Out:
# Testing lr=0.0001, hidden=[8, 4]
# lr=0.0001, hidden=[8, 4] -> acc=0.8040
# Testing lr=0.0001, hidden=[16, 8]
# lr=0.0001, hidden=[16, 8] -> acc=0.8029
# Testing lr=0.0001, hidden=[32, 16]
# lr=0.0001, hidden=[32, 16] -> acc=0.7486
# Testing lr=0.001, hidden=[8, 4]
# lr=0.001, hidden=[8, 4] -> acc=0.9934
# Testing lr=0.001, hidden=[16, 8]
# lr=0.001, hidden=[16, 8] -> acc=0.9900
# Testing lr=0.001, hidden=[32, 16]
# lr=0.001, hidden=[32, 16] -> acc=0.9745
# Testing lr=0.01, hidden=[8, 4]
# lr=0.01, hidden=[8, 4] -> acc=0.9989
# Testing lr=0.01, hidden=[16, 8]
# lr=0.01, hidden=[16, 8] -> acc=1.0000
# Testing lr=0.01, hidden=[32, 16]
# lr=0.01, hidden=[32, 16] -> acc=1.0000
#
# BEST SETUP:
# learning_rate = 0.01
# hidden_sizes  = [16, 8]
# best accuracy = 1.0
#
# FINAL TEST ACC: 1.0

# %% [markdown]
# ### 10) Dataset 3: Adult
#
# Read about the Adult dataset: https://archive.ics.uci.edu/dataset/2/adult
#
# **IMPORTANT NOTE:** This dataset is much larger than the previous two (48843 instances). If your code runs slow on your own computer, either run this on the compute-server, or you may exclude parts of this dataset. But you must keep a minimum of 10000 datapoints.

# %%
from sklearn import preprocessing # For one-hot-encoding and scaling if needed
from sklearn.model_selection import train_test_split
       
dataset_3 = pd.read_csv("adult.csv",na_values="?")
dataset_3=dataset_3.dropna()



x_features_raw=dataset_3.iloc[:,:-1]
y_target_raw=dataset_3.iloc[:,-1]

# encode y to 0/1 and one-hot
le=preprocessing.LabelEncoder()
y_target_encoded=le.fit_transform(y_target_raw)
y_one_hot=np.eye(2)[y_target_encoded]

# remove redundant column (educational-num is just a numeric version of education, so it doesn't add new info, and can cause issues with one-hot encoding)
x_features_raw = x_features_raw.drop(columns=["educational-num"])

# one-hot encode X
x_features_oh=pd.get_dummies(x_features_raw)
x=x_features_oh.values.astype(float)

# split BEFORE scaling (avoid leakage)
x_train, x_test, y_train, y_test = train_test_split(
    x, y_one_hot, test_size=0.2, random_state=42, stratify=y_target_encoded
)

# scale using train only
scaler=preprocessing.StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled  = scaler.transform(x_test)

# model creation and training
input_dim=x_train_scaled.shape[1]
neural_network=NeuralNet(input_dim=input_dim, output_dim=2, neurons=[32,16])

epochs = 50
loss_history = []
acc_history  = []

for ep in range(epochs):
    loss_ep = neural_network.train_net(x_train_scaled, y_train, batch_size=32, epochs=1, learning_rate=1e-3)
    loss_history.append(loss_ep[0])
    

    acc = calc_acc(neural_network, x_test_scaled, y_test)
    acc_history.append(acc)

plt.figure()
plt.plot(loss_history)
plt.title("Training loss per epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

plt.figure()
plt.plot(acc_history)
plt.title("Test accuracy per epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim(0, 1.05)
plt.show()

# %% [markdown]
# When hyper-parameter tuning, please write the parameters and network sizes you test here:
#
# * Parameter 1:
# * Parameter 2:
#
# * Neural network sizes:

# %%
# create validation split from TRAIN (scaled)
X_tr, X_val, y_tr, y_val = train_test_split(
    x_train_scaled, y_train, test_size=0.2, random_state=42,
    stratify=np.argmax(y_train, axis=1)   
)
learning_rates = [1e-4, 1e-3, 1e-2]
hidden_sizes   = [[8,4], [16,8], [32,16]]

results = [] 
# GRID SEARCH on VALIDATION SET
for lr in learning_rates:
    for hs in hidden_sizes:
        print(f"Testing lr={lr}, hidden={hs}")
        neural_network_sample = NeuralNet(input_dim=X_tr.shape[1], output_dim=2, neurons=hs)

        # Train for some epochs (not too many for tuning)
        train_loss, val_loss=neural_network_sample.train_net(X_tr, y_tr, batch_size=32, epochs=30, learning_rate=lr,use_validation_data=True)

        # Evaluate on test set
        val_acc = calc_acc(neural_network_sample, X_val, y_val)
        results.append((lr, hs, val_acc))
        print(f"Result: Accuracy = {val_acc:.4f}")
        print(f"lr={lr}, hidden={hs} -> acc={val_acc:.4f}")

best_lr, best_hs, best_val_acc = max(results, key=lambda t: t[2])

print("\nBEST SETUP: (by validation)")
print("learning_rate =", best_lr)
print("hidden_sizes  =", best_hs)
print("best accuracy =", best_val_acc)


# -----------------------------
# Train best model again, and track curves per epoch
# -----------------------------

neural_network_best = NeuralNet(input_dim=x_train_scaled.shape[1], output_dim=2, neurons=best_hs)

epochs = 50
loss_history = []
val_acc_history = []


for ep in range(epochs):
    # Train 1 epoch
    loss_ep = neural_network_best.train_net(x_train_scaled, y_train, batch_size=32, epochs=1, learning_rate=best_lr)
    loss_history.append(loss_ep[0])

    # Test accuracy after this epoch
    val_acc = calc_acc(neural_network_best, X_val, y_val)
    val_acc_history.append(val_acc)


#  Final TEST accuracy (ONE TIME)
final_test_acc = calc_acc(neural_network_best, x_test_scaled, y_test)
print("\nFINAL TEST ACC:", final_test_acc)

# Plot loss
plt.figure()
plt.plot(loss_history)
plt.title("Training loss per epoch (best model)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# Plot test accuracy
plt.figure()
plt.plot(val_acc_history)
plt.title("Validation accuracy per epoch (best model)")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim(0,1.05)
plt.show()
# TODO: Visualize the loss after hyper-parameter tuning for each epoch

# TODO: Visulaize the test accuracy after hyper-parameter tuning for each epoch
# Out:
# Testing lr=0.0001, hidden=[8, 4]
# Result: Accuracy = 0.7757
# lr=0.0001, hidden=[8, 4] -> acc=0.7757
# Testing lr=0.0001, hidden=[16, 8]
# Result: Accuracy = 0.7500
# lr=0.0001, hidden=[16, 8] -> acc=0.7500
# Testing lr=0.0001, hidden=[32, 16]
# Result: Accuracy = 0.7615
# lr=0.0001, hidden=[32, 16] -> acc=0.7615
# Testing lr=0.001, hidden=[8, 4]
# Result: Accuracy = 0.7852
# lr=0.001, hidden=[8, 4] -> acc=0.7852
# Testing lr=0.001, hidden=[16, 8]
# Result: Accuracy = 0.7975
# lr=0.001, hidden=[16, 8] -> acc=0.7975
# Testing lr=0.001, hidden=[32, 16]
# Result: Accuracy = 0.8223
# lr=0.001, hidden=[32, 16] -> acc=0.8223
# Testing lr=0.01, hidden=[8, 4]
# Result: Accuracy = 0.8326
# lr=0.01, hidden=[8, 4] -> acc=0.8326
# Testing lr=0.01, hidden=[16, 8]
# Result: Accuracy = 0.8315
# lr=0.01, hidden=[16, 8] -> acc=0.8315
# Testing lr=0.01, hidden=[32, 16]
# Result: Accuracy = 0.8339
# lr=0.01, hidden=[32, 16] -> acc=0.8339
#
# BEST SETUP: (by validation)
# learning_rate = 0.01
# hidden_sizes  = [32, 16]
# best accuracy = 0.8338861249309011
#
# FINAL TEST ACC: 0.8449972360420122

# %% [markdown]
# # Questions for examination:
#
# In addition to completing the assignment with all its tasks, you should also prepare to answer the following questions:
#
# 1) Why would we want to use different activation functions?
#
# 2) Why would we want to use different loss functions?
#
# 3) Why are neural networks sensitive to large input values?
#
# 4) What is the role of the bias?
#
# 5) What is the purpose of hyper-parameter tuning?

# %% [markdown]
# # Finished!
#
# Was part of the setup incorrect? Did you spot any inconsistencies in the assignment? Could something improve?
#
# If so, please write them and send via email and send it to:
#
# * marcus.gullstrand@ju.se
#
# Thank you!
